# %% [markdown]
# <hr style="height:2px;">
#
# # Neural network training for denoising of X-ray Holographic Nanotomography data
#
# Adapted from example notebook.
#
# This notebook demonstrates training a CARE model for a 3D denoising task, assuming that training data was already generated via [1_datagen.ipynb](1_datagen.ipynb) and has been saved to disk to the file `datapath + `my_training_data.npz``. (Set datapath below.)
#
# Note that training a neural network for actual use should be done on more (representative) data and with more training time.
#
# More documentation is available at http://csbdeep.bioimagecomputing.com/doc/.

# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from tifffile import imread
from csbdeep.utils import axes_dict, plot_some, plot_history
from csbdeep.utils.tf import limit_gpu_memory
from csbdeep.io import load_training_data
from csbdeep.models import Config, CARE
# Out:
# 2021-07-20 16:49:12.930517: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# The TensorFlow backend uses all available GPU memory by default, hence it can be useful to limit it:

# %%
limit_gpu_memory(fraction=4/5)
# Out:
# 2021-07-20 14:18:44.339850: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-20 14:18:44.343787: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-07-20 14:18:44.478230: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 14:18:44.479341: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 14:18:44.480410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:83:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 14:18:44.481473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:84:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 14:18:44.481513: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-07-20 14:18:45.269653: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-07-20 14:18:45.269800: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-07-20 14:18:46.000470: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-07-20 14:18:46.037259: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-07-20 14:18:46.298315: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-07-20 14:18:46.584911: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-07-20 14:18:49.113664: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-07-20 14:18:49.128022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_22042/475828282.py in <module>
# ----> 1 limit_gpu_memory(fraction=4/5)
#
# /mnt/orchestra_nfs/users/jlr54/envs/miniconda3/envs/n2v/lib/python3.7/site-packages/csbdeep/utils/tf.py in limit_gpu_memory(fraction, allow_growth, total_memory)
#      88         if gpus:
#      89             if fraction is not None:
# ---> 90                 np.isscalar(total_memory) or _raise(ValueError("'total_memory' must be provided when using TensorFlow 2."))
#      91                 vdc = tf.config.experimental.VirtualDeviceConfiguration(memory_limit=int(np.ceil(total_memory*fraction)))
#      92             try:
#
# /mnt/orchestra_nfs/users/jlr54/envs/miniconda3/envs/n2v/lib/python3.7/site-packages/csbdeep/utils/utils.py in _raise(e)
#      89 def _raise(e):
#      90     if isinstance(e, BaseException):
# ---> 91         raise e
#      92     else:
#      93         raise ValueError(e)
#
# ValueError: 'total_memory' must be provided when using TensorFlow 2.

# %%
# SET DATA PATH
datapath = "/n/groups/htem/ESRF_id16a/tomo_ML/ReducedAnglesXray/CARE/mCTX/"

# %% [markdown]
# <hr style="height:2px;">
#
# # Training data
#
# Load training data generated via [1_datagen.ipynb](1_datagen.ipynb), use 10% as validation data.

# %%
(X,Y), (X_val,Y_val), axes = load_training_data(datapath + 'my_training_data.npz', validation_split=0.1, verbose=True)

c = axes_dict(axes)['C']
n_channel_in, n_channel_out = X.shape[c], Y.shape[c]
# Out:
# number of training images:	 922
# number of validation images:	 102
# image size (3D):		 (16, 64, 64)
# axes:				 SZYXC
# channels in / out:		 1 / 1

# %%
plt.figure(figsize=(12,5))
plot_some(X_val[:5],Y_val[:5])
plt.suptitle('5 example validation patches (top row: source, bottom row: target)');

# %% [markdown]
# <hr style="height:2px;">
#
# # CARE model
#
# Before we construct the actual CARE model, we have to define its configuration via a `Config` object, which includes
# * parameters of the underlying neural network,
# * the learning rate,
# * the number of parameter updates per epoch,
# * the loss function, and
# * whether the model is probabilistic or not.
#
# The defaults should be sensible in many cases, so a change should only be necessary if the training process fails.
#
# ---
#
# <span style="color:red;font-weight:bold;">Important</span>: Note that for this notebook we use a very small number of update steps per epoch for immediate feedback, whereas this number should be increased considerably (e.g. `train_steps_per_epoch=400`) to obtain a well-trained model.

# %%
config = Config(axes, n_channel_in, n_channel_out, train_steps_per_epoch=100, unet_kern_size=5)
print(config)
vars(config)
# Out:
# Config(axes='ZYXC', n_channel_in=1, n_channel_out=1, n_dim=3, probabilistic=False, train_batch_size=16, train_checkpoint='weights_best.h5', train_checkpoint_epoch='weights_now.h5', train_checkpoint_last='weights_last.h5', train_epochs=100, train_learning_rate=0.0004, train_loss='mae', train_reduce_lr={'factor': 0.5, 'patience': 10, 'min_delta': 0}, train_steps_per_epoch=100, train_tensorboard=True, unet_input_shape=(None, None, None, 1), unet_kern_size=5, unet_last_activation='linear', unet_n_depth=2, unet_n_first=32, unet_residual=True)
# {'n_dim': 3,
#  'axes': 'ZYXC',
#  'n_channel_in': 1,
#  'n_channel_out': 1,
#  'train_checkpoint': 'weights_best.h5',
#  'train_checkpoint_last': 'weights_last.h5',
#  'train_checkpoint_epoch': 'weights_now.h5',
#  'probabilistic': False,
#  'unet_residual': True,
#  'unet_n_depth': 2,
#  'unet_kern_size': 5,
#  'unet_n_first': 32,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, None, 1),
#  'train_loss': 'mae',
#  'train_epochs': 100,
#  'train_steps_per_epoch': 100,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 16,
#  'train_tensorboard': True,
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10, 'min_delta': 0}}

# %% [markdown]
# We now create a CARE model with the chosen configuration:

# %%
model = CARE(config, 'my_model_900p_100', basedir='models')
# Out:
# /mnt/orchestra_nfs/users/jlr54/envs/miniconda3/envs/n2v/lib/python3.7/site-packages/csbdeep/models/base_model.py:148: UserWarning: output path for model already exists, files may be overwritten: /n/groups/htem/users/jlr54/CSBDeep/jrho/denoising3D/models/my_model_900p_100
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))
# 2021-07-20 16:49:33.561545: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-20 16:49:33.562894: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-07-20 16:49:33.692773: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:33.693849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:33.694919: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:83:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:33.695982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:84:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:33.696019: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-07-20 16:49:33.700341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-07-20 16:49:33.700400: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-07-20 16:49:33.703342: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-07-20 16:49:33.704793: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-07-20 16:49:33.708751: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-07-20 16:49:33.711450: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-07-20 16:49:33.718980: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-07-20 16:49:33.727130: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2021-07-20 16:49:33.727764: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-07-20 16:49:35.851919: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:35.852942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:35.853941: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:83:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:35.854942: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:84:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-20 16:49:35.855000: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-07-20 16:49:35.855049: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-07-20 16:49:35.855085: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-07-20 16:49:35.855120: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-07-20 16:49:35.855154: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-07-20 16:49:35.855189: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-07-20 16:49:35.855224: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-07-20 16:49:35.855259: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-07-20 16:49:35.862901: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2021-07-20 16:49:35.862974: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-07-20 16:49:38.958342: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-20 16:49:38.958390: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1 2 3
# 2021-07-20 16:49:38.958403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N N N N
# 2021-07-20 16:49:38.958411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N N N N
# 2021-07-20 16:49:38.958419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 2:   N N N N
# 2021-07-20 16:49:38.958427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 3:   N N N N
# 2021-07-20 16:49:38.964675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7234 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080, pci bus id: 0000:02:00.0, compute capability: 7.5)
# 2021-07-20 16:49:38.967055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 7252 MB memory) -> physical GPU (device: 1, name: GeForce RTX 2080, pci bus id: 0000:03:00.0, compute capability: 7.5)
# 2021-07-20 16:49:38.969210: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 7252 MB memory) -> physical GPU (device: 2, name: GeForce RTX 2080, pci bus id: 0000:83:00.0, compute capability: 7.5)
# 2021-07-20 16:49:38.971426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 7252 MB memory) -> physical GPU (device: 3, name: GeForce RTX 2080, pci bus id: 0000:84:00.0, compute capability: 7.5)
# 2021-07-20 16:49:38.971737: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %% [markdown]
# <hr style="height:2px;">
#
# # Training
#
# Training the model will likely take some time. We recommend to monitor the progress with [TensorBoard](https://www.tensorflow.org/programmers_guide/summaries_and_tensorboard) (example below), which allows you to inspect the losses during training.
# Furthermore, you can look at the predictions for some of the validation images, which can be helpful to recognize problems early on.
#
# You can start TensorBoard from the current working directory with `tensorboard --logdir=.`
# Then connect to [http://localhost:6006/](http://localhost:6006/) with your browser.
#
# ![](http://csbdeep.bioimagecomputing.com/img/tensorboard_denoising3D.png)

# %%
history = model.train(X,Y, validation_data=(X_val,Y_val))
# Out:
# bosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function loss_mse.<locals>.mse at 0x7f7b82191170> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function loss_mae.<locals>.mae at 0x7f7b82191290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function loss_mae.<locals>.mae at 0x7f7b82191290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2021-07-20 16:49:47.997891: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-07-20 16:49:49.467822: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2021-07-20 16:49:49.617145: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2021-07-20 16:49:50.345228: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
#   6/100 [>.............................] - ETA: 1:00 - loss: 0.0758 - mse: 0.0097 - mae: 0.0758WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1558s vs `on_train_batch_end` time: 0.4043s). Check your callbacks.
# 100/100 [==============================] - 112s 912ms/step - loss: 0.0602 - mse: 0.0059 - mae: 0.0602 - val_loss: 0.0526 - val_mse: 0.0044 - val_mae: 0.0526
# Epoch 2/100
# 100/100 [==============================] - 66s 662ms/step - loss: 0.0514 - mse: 0.0042 - mae: 0.0514 - val_loss: 0.0501 - val_mse: 0.0040 - val_mae: 0.0501
# Epoch 3/100
# 100/100 [==============================] - 68s 681ms/step - loss: 0.0499 - mse: 0.0039 - mae: 0.0499 - val_loss: 0.0494 - val_mse: 0.0039 - val_mae: 0.0494
# Epoch 4/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0496 - mse: 0.0039 - mae: 0.0496 - val_loss: 0.0492 - val_mse: 0.0038 - val_mae: 0.0492
# Epoch 5/100
# 100/100 [==============================] - 69s 687ms/step - loss: 0.0491 - mse: 0.0038 - mae: 0.0491 - val_loss: 0.0491 - val_mse: 0.0038 - val_mae: 0.0491
# Epoch 6/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0492 - mse: 0.0038 - mae: 0.0492 - val_loss: 0.0490 - val_mse: 0.0038 - val_mae: 0.0490
# Epoch 7/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0490 - mse: 0.0038 - mae: 0.0490 - val_loss: 0.0489 - val_mse: 0.0038 - val_mae: 0.0489
# Epoch 8/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0487 - mse: 0.0038 - mae: 0.0487 - val_loss: 0.0488 - val_mse: 0.0038 - val_mae: 0.0488
# Epoch 9/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0490 - mse: 0.0038 - mae: 0.0490 - val_loss: 0.0489 - val_mse: 0.0038 - val_mae: 0.0489
# Epoch 10/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0487 - mse: 0.0038 - mae: 0.0487 - val_loss: 0.0487 - val_mse: 0.0037 - val_mae: 0.0487
# Epoch 11/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0486 - mse: 0.0037 - mae: 0.0486 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 12/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0486 - mse: 0.0037 - mae: 0.0486 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 13/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0486 - mse: 0.0037 - mae: 0.0486 - val_loss: 0.0487 - val_mse: 0.0037 - val_mae: 0.0487
# Epoch 14/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0485 - mse: 0.0037 - mae: 0.0485 - val_loss: 0.0487 - val_mse: 0.0037 - val_mae: 0.0487
# Epoch 15/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0485 - mse: 0.0037 - mae: 0.0485 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 16/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0485 - mse: 0.0037 - mae: 0.0485 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 17/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0484 - mse: 0.0037 - mae: 0.0484 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 18/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0483 - mse: 0.0037 - mae: 0.0483 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 19/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0483 - mse: 0.0037 - mae: 0.0483 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 20/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0482 - mse: 0.0037 - mae: 0.0482 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 21/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0481 - mse: 0.0037 - mae: 0.0481 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 22/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0479 - mse: 0.0036 - mae: 0.0479 - val_loss: 0.0488 - val_mse: 0.0038 - val_mae: 0.0488
# Epoch 23/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0479 - mse: 0.0036 - mae: 0.0479 - val_loss: 0.0486 - val_mse: 0.0037 - val_mae: 0.0486
# Epoch 24/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0478 - mse: 0.0036 - mae: 0.0478 - val_loss: 0.0489 - val_mse: 0.0038 - val_mae: 0.0489
# Epoch 25/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0475 - mse: 0.0036 - mae: 0.0475 - val_loss: 0.0489 - val_mse: 0.0038 - val_mae: 0.0489
# Epoch 26/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0472 - mse: 0.0035 - mae: 0.0472 - val_loss: 0.0489 - val_mse: 0.0038 - val_mae: 0.0489
# Epoch 27/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0470 - mse: 0.0035 - mae: 0.0470 - val_loss: 0.0494 - val_mse: 0.0039 - val_mae: 0.0494
# Epoch 28/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0469 - mse: 0.0035 - mae: 0.0469 - val_loss: 0.0497 - val_mse: 0.0039 - val_mae: 0.0497
# Epoch 29/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0466 - mse: 0.0034 - mae: 0.0466 - val_loss: 0.0495 - val_mse: 0.0039 - val_mae: 0.0495
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 30/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0460 - mse: 0.0033 - mae: 0.0460 - val_loss: 0.0496 - val_mse: 0.0039 - val_mae: 0.0496
# Epoch 31/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0454 - mse: 0.0033 - mae: 0.0454 - val_loss: 0.0499 - val_mse: 0.0039 - val_mae: 0.0499
# Epoch 32/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0451 - mse: 0.0032 - mae: 0.0451 - val_loss: 0.0501 - val_mse: 0.0040 - val_mae: 0.0501
# Epoch 33/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0448 - mse: 0.0032 - mae: 0.0448 - val_loss: 0.0504 - val_mse: 0.0040 - val_mae: 0.0504
# Epoch 34/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0445 - mse: 0.0031 - mae: 0.0445 - val_loss: 0.0505 - val_mse: 0.0040 - val_mae: 0.0505
# Epoch 35/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0440 - mse: 0.0031 - mae: 0.0440 - val_loss: 0.0506 - val_mse: 0.0041 - val_mae: 0.0506
# Epoch 36/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0437 - mse: 0.0030 - mae: 0.0437 - val_loss: 0.0508 - val_mse: 0.0041 - val_mae: 0.0508
# Epoch 37/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0433 - mse: 0.0030 - mae: 0.0433 - val_loss: 0.0511 - val_mse: 0.0041 - val_mae: 0.0511
# Epoch 38/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0430 - mse: 0.0029 - mae: 0.0430 - val_loss: 0.0512 - val_mse: 0.0042 - val_mae: 0.0512
# Epoch 39/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0424 - mse: 0.0029 - mae: 0.0424 - val_loss: 0.0517 - val_mse: 0.0042 - val_mae: 0.0517
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 40/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0419 - mse: 0.0028 - mae: 0.0419 - val_loss: 0.0522 - val_mse: 0.0043 - val_mae: 0.0522
# Epoch 41/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0415 - mse: 0.0028 - mae: 0.0415 - val_loss: 0.0526 - val_mse: 0.0044 - val_mae: 0.0526
# Epoch 42/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0410 - mse: 0.0027 - mae: 0.0410 - val_loss: 0.0528 - val_mse: 0.0044 - val_mae: 0.0528
# Epoch 43/100
# 100/100 [==============================] - 69s 685ms/step - loss: 0.0409 - mse: 0.0027 - mae: 0.0409 - val_loss: 0.0529 - val_mse: 0.0044 - val_mae: 0.0529
# Epoch 44/100
# 100/100 [==============================] - 69s 685ms/step - loss: 0.0406 - mse: 0.0026 - mae: 0.0406 - val_loss: 0.0532 - val_mse: 0.0045 - val_mae: 0.0532
# Epoch 45/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0403 - mse: 0.0026 - mae: 0.0403 - val_loss: 0.0534 - val_mse: 0.0045 - val_mae: 0.0534
# Epoch 46/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0401 - mse: 0.0026 - mae: 0.0401 - val_loss: 0.0533 - val_mse: 0.0045 - val_mae: 0.0533
# Epoch 47/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0399 - mse: 0.0025 - mae: 0.0399 - val_loss: 0.0538 - val_mse: 0.0046 - val_mae: 0.0538
# Epoch 48/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0399 - mse: 0.0025 - mae: 0.0399 - val_loss: 0.0540 - val_mse: 0.0046 - val_mae: 0.0540
# Epoch 49/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0395 - mse: 0.0025 - mae: 0.0395 - val_loss: 0.0541 - val_mse: 0.0046 - val_mae: 0.0541
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 50/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0391 - mse: 0.0025 - mae: 0.0391 - val_loss: 0.0543 - val_mse: 0.0047 - val_mae: 0.0543
# Epoch 51/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0389 - mse: 0.0024 - mae: 0.0389 - val_loss: 0.0547 - val_mse: 0.0047 - val_mae: 0.0547
# Epoch 52/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0387 - mse: 0.0024 - mae: 0.0387 - val_loss: 0.0547 - val_mse: 0.0048 - val_mae: 0.0547
# Epoch 53/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0387 - mse: 0.0024 - mae: 0.0387 - val_loss: 0.0549 - val_mse: 0.0048 - val_mae: 0.0549
# Epoch 54/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0385 - mse: 0.0024 - mae: 0.0385 - val_loss: 0.0551 - val_mse: 0.0048 - val_mae: 0.0551
# Epoch 55/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0384 - mse: 0.0024 - mae: 0.0384 - val_loss: 0.0552 - val_mse: 0.0048 - val_mae: 0.0552
# Epoch 56/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0383 - mse: 0.0024 - mae: 0.0383 - val_loss: 0.0553 - val_mse: 0.0049 - val_mae: 0.0553
# Epoch 57/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0381 - mse: 0.0023 - mae: 0.0381 - val_loss: 0.0554 - val_mse: 0.0049 - val_mae: 0.0554
# Epoch 58/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0380 - mse: 0.0023 - mae: 0.0380 - val_loss: 0.0555 - val_mse: 0.0049 - val_mae: 0.0555
# Epoch 59/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0379 - mse: 0.0023 - mae: 0.0379 - val_loss: 0.0558 - val_mse: 0.0049 - val_mae: 0.0558
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 60/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0378 - mse: 0.0023 - mae: 0.0378 - val_loss: 0.0559 - val_mse: 0.0050 - val_mae: 0.0559
# Epoch 61/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0378 - mse: 0.0023 - mae: 0.0378 - val_loss: 0.0559 - val_mse: 0.0050 - val_mae: 0.0559
# Epoch 62/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0376 - mse: 0.0023 - mae: 0.0376 - val_loss: 0.0560 - val_mse: 0.0050 - val_mae: 0.0560
# Epoch 63/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0377 - mse: 0.0023 - mae: 0.0377 - val_loss: 0.0561 - val_mse: 0.0050 - val_mae: 0.0561
# Epoch 64/100
# 100/100 [==============================] - 69s 685ms/step - loss: 0.0376 - mse: 0.0023 - mae: 0.0376 - val_loss: 0.0561 - val_mse: 0.0050 - val_mae: 0.0561
# Epoch 65/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0376 - mse: 0.0023 - mae: 0.0376 - val_loss: 0.0562 - val_mse: 0.0050 - val_mae: 0.0562
# Epoch 66/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0375 - mse: 0.0023 - mae: 0.0375 - val_loss: 0.0563 - val_mse: 0.0050 - val_mae: 0.0563
# Epoch 67/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0374 - mse: 0.0023 - mae: 0.0374 - val_loss: 0.0564 - val_mse: 0.0051 - val_mae: 0.0564
# Epoch 68/100
# 100/100 [==============================] - 69s 685ms/step - loss: 0.0373 - mse: 0.0022 - mae: 0.0373 - val_loss: 0.0564 - val_mse: 0.0051 - val_mae: 0.0564
# Epoch 69/100
# 100/100 [==============================] - 69s 685ms/step - loss: 0.0373 - mse: 0.0022 - mae: 0.0373 - val_loss: 0.0566 - val_mse: 0.0051 - val_mae: 0.0566
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 70/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0373 - mse: 0.0022 - mae: 0.0373 - val_loss: 0.0566 - val_mse: 0.0051 - val_mae: 0.0566
# Epoch 71/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0371 - mse: 0.0022 - mae: 0.0371 - val_loss: 0.0566 - val_mse: 0.0051 - val_mae: 0.0566
# Epoch 72/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0371 - mse: 0.0022 - mae: 0.0371 - val_loss: 0.0567 - val_mse: 0.0051 - val_mae: 0.0567
# Epoch 73/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0371 - mse: 0.0022 - mae: 0.0371 - val_loss: 0.0568 - val_mse: 0.0051 - val_mae: 0.0568
# Epoch 74/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0370 - mse: 0.0022 - mae: 0.0370 - val_loss: 0.0568 - val_mse: 0.0051 - val_mae: 0.0568
# Epoch 75/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0371 - mse: 0.0022 - mae: 0.0371 - val_loss: 0.0568 - val_mse: 0.0051 - val_mae: 0.0568
# Epoch 76/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0370 - mse: 0.0022 - mae: 0.0370 - val_loss: 0.0569 - val_mse: 0.0051 - val_mae: 0.0569
# Epoch 77/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0370 - mse: 0.0022 - mae: 0.0370 - val_loss: 0.0569 - val_mse: 0.0051 - val_mae: 0.0569
# Epoch 78/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0370 - mse: 0.0022 - mae: 0.0370 - val_loss: 0.0570 - val_mse: 0.0052 - val_mae: 0.0570
# Epoch 79/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0370 - mse: 0.0022 - mae: 0.0370 - val_loss: 0.0570 - val_mse: 0.0052 - val_mae: 0.0570
#
# Epoch 00079: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 80/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0570 - val_mse: 0.0052 - val_mae: 0.0570
# Epoch 81/100
# 100/100 [==============================] - 68s 682ms/step - loss: 0.0370 - mse: 0.0022 - mae: 0.0370 - val_loss: 0.0570 - val_mse: 0.0052 - val_mae: 0.0570
# Epoch 82/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0369 - mse: 0.0022 - mae: 0.0369 - val_loss: 0.0571 - val_mse: 0.0052 - val_mae: 0.0571
# Epoch 83/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0571 - val_mse: 0.0052 - val_mae: 0.0571
# Epoch 84/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0571 - val_mse: 0.0052 - val_mae: 0.0571
# Epoch 85/100
# 100/100 [==============================] - 68s 683ms/step - loss: 0.0370 - mse: 0.0022 - mae: 0.0370 - val_loss: 0.0571 - val_mse: 0.0052 - val_mae: 0.0571
# Epoch 86/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0572 - val_mse: 0.0052 - val_mae: 0.0572
# Epoch 87/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0572 - val_mse: 0.0052 - val_mae: 0.0572
# Epoch 88/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0572 - val_mse: 0.0052 - val_mae: 0.0572
# Epoch 89/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0572 - val_mse: 0.0052 - val_mae: 0.0572
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 90/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0572 - val_mse: 0.0052 - val_mae: 0.0572
# Epoch 91/100
# 100/100 [==============================] - 69s 686ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0572 - val_mse: 0.0052 - val_mae: 0.0572
# Epoch 92/100
# 100/100 [==============================] - 69s 685ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0573 - val_mse: 0.0052 - val_mae: 0.0573
# Epoch 93/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0572 - val_mse: 0.0052 - val_mae: 0.0572
# Epoch 94/100
# 100/100 [==============================] - 69s 685ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0573 - val_mse: 0.0052 - val_mae: 0.0573
# Epoch 95/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0573 - val_mse: 0.0052 - val_mae: 0.0573
# Epoch 96/100
# 100/100 [==============================] - 68s 684ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0573 - val_mse: 0.0052 - val_mae: 0.0573
# Epoch 97/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0368 - mse: 0.0022 - mae: 0.0368 - val_loss: 0.0573 - val_mse: 0.0052 - val_mae: 0.0573
# Epoch 98/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0573 - val_mse: 0.0052 - val_mae: 0.0573
# Epoch 99/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0366 - mse: 0.0022 - mae: 0.0366 - val_loss: 0.0573 - val_mse: 0.0052 - val_mae: 0.0573
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 100/100
# 100/100 [==============================] - 68s 685ms/step - loss: 0.0367 - mse: 0.0022 - mae: 0.0367 - val_loss: 0.0574 - val_mse: 0.0052 - val_mae: 0.0574
#
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# Plot final training history (available in TensorBoard during training):

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss'],['mse','val_mse','mae','val_mae']);
# Out:
# ['loss', 'lr', 'mae', 'mse', 'val_loss', 'val_mae', 'val_mse']

# %% [markdown]
# <hr style="height:2px;">
#
# # Evaluation
#
# Example results for validation images.

# %%
plt.figure(figsize=(12,7))
_P = model.keras_model.predict(X_val[:5])
if config.probabilistic:
    _P = _P[...,:(_P.shape[-1]//2)]
plot_some(X_val[:5],Y_val[:5],_P,pmax=99.5)
plt.suptitle('5 example validation patches\n'      
             'top row: input (source),  '          
             'middle row: target (ground truth),  '
             'bottom row: predicted from source');

# %% [markdown]
# <hr style="height:2px;">
#
# # Export model to be used with CSBDeep **Fiji** plugins and **KNIME** workflows
#
# See https://github.com/CSBDeep/CSBDeep_website/wiki/Your-Model-in-Fiji for details.

# %%
model.export_TF()
# Out:
# 2021-07-21 09:34:01.128311: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-21 09:34:01.129382: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-21 09:34:01.130434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 2 with properties:
# pciBusID: 0000:83:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-21 09:34:01.131453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 3 with properties:
# pciBusID: 0000:84:00.0 name: GeForce RTX 2080 computeCapability: 7.5
# coreClock: 1.71GHz coreCount: 46 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.23GiB/s
# 2021-07-21 09:34:01.131541: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-07-21 09:34:01.131596: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-07-21 09:34:01.131640: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-07-21 09:34:01.131685: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-07-21 09:34:01.131730: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-07-21 09:34:01.131774: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-07-21 09:34:01.131819: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-07-21 09:34:01.131865: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-07-21 09:34:01.139013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1, 2, 3
# 2021-07-21 09:34:01.139362: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-07-21 09:34:01.139383: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1 2 3
# 2021-07-21 09:34:01.139394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N N N N
# 2021-07-21 09:34:01.139403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N N N N
# 2021-07-21 09:34:01.139411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 2:   N N N N
# 2021-07-21 09:34:01.139419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 3:   N N N N
# 2021-07-21 09:34:01.143939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7234 MB memory) -> physical GPU (device: 0, name: GeForce RTX 2080, pci bus id: 0000:02:00.0, compute capability: 7.5)
# 2021-07-21 09:34:01.144951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 7252 MB memory) -> physical GPU (device: 1, name: GeForce RTX 2080, pci bus id: 0000:03:00.0, compute capability: 7.5)
# 2021-07-21 09:34:01.145962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:2 with 7252 MB memory) -> physical GPU (device: 2, name: GeForce RTX 2080, pci bus id: 0000:83:00.0, compute capability: 7.5)
# 2021-07-21 09:34:01.146988: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:3 with 7252 MB memory) -> physical GPU (device: 3, name: GeForce RTX 2080, pci bus id: 0000:84:00.0, compute capability: 7.5)
# 2021-07-21 09:34:01.147026: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-07-21 09:34:01.169549: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# WARNING:tensorflow:From /mnt/orchestra_nfs/users/jlr54/envs/miniconda3/envs/n2v/lib/python3.7/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /tmp/tmplgnsdtw7/model/saved_model.pb
#
# Model exported in TensorFlow's SavedModel format:
# /n/groups/htem/users/jlr54/CSBDeep/jrho/denoising3D/models/my_model_900p_100/TF_SavedModel.zip
